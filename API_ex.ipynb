# %% [markdown]
# # `APP` - Full Code:
# For specific function explanation see the **Testing** section below:

# %% [markdown]
# # Testing:
# We will test each function singularly to demonstrate how the output looks. This will also allow users to try and modify the function in case they want to add extra elements to their request output.

# %% [markdown]
# ## Importing required libreries:

# %%
import pandas as pd
from flask import Flask,jsonify, json, request, render_template
import requests
import itertools
#import plotly.graph_objs as go
#import plotly.plotly as py
#from plotly.utils import PlotlyJSONEncoder
from pprint import pprint
#import requests_cache

# %% [markdown]
# ## Defining support Function `clean_col` :

# %%
def clean_col(inputlst):
    col_list = []
    for col in inputlst:
        col = col.strip()
        col = col.lower()
        col = col.replace(" ", "_")
        col = col.replace("(", "")
        col = col.replace(")", "")
        col = col.replace("-", "_")
        col = col.strip()
        col_list.append(col)
    return col_list

# %% [markdown]
# ## 1. `Get_content`:
# `get_content` allows the user to extract all the records from the Police API. Nevertheless, these records are not layed out in a functional format and can be difficult to interpret if the users do not have sufficient experience with dictionary and json files.

# %%
def get_content(date, n_records): #"get_records" has two parameters:
                                      #1. "date" parameter
                                      #2. "n_records" paramter, which can be either All or an interger
    
    #Setting the API url:
    crime_url_template = 'https://data.police.uk/api/outcomes-at-location?lat={lat}&lng={lng}&date={data}'

    my_latitude = '51.509865' #The latitude of London City
    my_longitude = '-0.118092' #The longitute of London City
    extract_date = str(date) #Converting the "date" parameter given by the path to a string
    year = extract_date[0:4] #Slicing date in "year" (ex. "2018")
    month = extract_date[4:len(extract_date)] #Slicing date in "month" (ex. "11")
    my_date = year + "-" + month #Connecting "year" and "month" whilst adding a dash (ex. "2018-11")
   
    #Calling format on the API string to change {lat}, {lng}, {data} into the above-set paramters:
    crime_url = crime_url_template.format(
        lat = my_latitude,
        lng = my_longitude,
        data = my_date) 

    #Calling ".get" function to establish a connection with the Police API:
    resp = requests.get(crime_url)
    
    #If a "status_code" equal to 200 is returned then the resp in "json" format is returned:
    if resp.status_code == 200:
        all_crime_data = resp.json()

    #Else return the "status_code" of the respons:
    else:
        print(resp.status_code)

# %% [markdown]
# This is an example of the output of the `get_content` function:

# %%
get_content("201811")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d7c4ddd7b088> in <module>()
# ----> 1 get_content("201811")
#
# TypeError: get_content() missing 1 required positional argument: 'n_records'

# %% [markdown]
# The `get_content` function is only a building block for the more advanced function that the app will have. Indeed, in the App there is no path that allows the users to call `get_content`. Nevertheless, you will notice that each of the function used in the app uses the same logic of `get_content` to extract the records from the API. Hence, it is useful to see what it does, especially if one wants to change the logic of one of the apps functions.

# %% [markdown]
# ## 2. `Get Records`:
# The `get_records` functions allows the users to extract all the records in a more polished format. Indeed this time each record has one single key and all the values are specified under that key. This removes abstraction and allows the users to benefit from a neat output when formulating his request.
#
# `get_records` allows for a more complex logic when dictating the `curl` request. It allows the user to decide either the amount of records he wants to extract or to extract all the records. Finally, it allows advices the user if the number of records he tried request are more than the the total amount of records.
#
# `get_records` takes in a `date` directly from the path specified in the `curl` request.

# %%
def get_records(date, n_records): #"get_records" has two parameters:
                                      #1. "date" parameter
                                      #2. "n_records" paramter, which can be either All or a number, any other value will return an error:
    
    #Setting the API url:
    crime_url_template = 'https://data.police.uk/api/outcomes-at-location?lat={lat}&lng={lng}&date={data}'

    my_latitude = '51.509865' #The latitude of London City
    my_longitude = '-0.118092' #The longitute of London City
    extract_date = str(date) #Converting the "date" parameter given by the path to a string
    year = extract_date[0:4] #Slicing date in "year" (ex. "2018")
    month = extract_date[4:len(extract_date)] #Slicing date in "month" (ex. "11")
    my_date = year + "-" + month #Connecting "year" and "month" whilst adding a dash (ex. "2018-11")
   
    #Calling format on the API string to change {lat}, {lng}, {data} into the above-set paramters:
    crime_url = crime_url_template.format(
        lat = my_latitude,
        lng = my_longitude,
        data = my_date) 

    #Calling ".get" function to establish a connection with the Police API:
    resp = requests.get(crime_url)
    
    #If a "status_code" equal to 200 is returned then the resp in "json" format is returned:
    if resp.status_code == 200:
        all_crime_data = resp.json()

    #Else return the "status_code" of the respons:
    else:
        print(resp.status_code)
    
    #Creating a set of list to assign each value for each entry in the dictionary (see Mini_Project.ipynb)
    codes = []
    procedures = []
    dates = []
    person_ids = []
    crime_categories = []
    location_types = []
    latitudes = []
    longitudes = []
    street_ids = []
    street_names = []
    contexts = []
    persistent_ids = []
    crime_ids = []
    location_subtypes = []
    months = []

    #Calling a loop for every entry in the dictionary that has been returned from the response:
    for i in range(len(all_crime_data)):

    #Assigning each "i" value for each iteration to a variable:
        code = all_crime_data[i]["category"]["code"]
        procedure = all_crime_data[i]["category"]["name"]
        date =  all_crime_data[i]["date"]
        person_id = all_crime_data[i]["person_id"]
        crime_category = all_crime_data[i]["crime"]["category"]
        location_type = all_crime_data[i]["crime"]["location_type"]
        latitude = all_crime_data[i]["crime"]["location"]["latitude"]
        longitude = all_crime_data[i]["crime"]["location"]["longitude"]
        street_id = all_crime_data[i]["crime"]["location"]["street"]["id"]
        street_name = all_crime_data[i]["crime"]["location"]["street"]["name"]
        context = all_crime_data[i]["crime"]["context"]
        persistent_id = all_crime_data[i]["crime"]["persistent_id"]
        crime_id = all_crime_data[i]["crime"]["id"]
        location_subtype = all_crime_data[i]["crime"]["location_subtype"]
        month = all_crime_data[i]["crime"]["month"]
        
    #Appending each variable to the respective list:
        codes.append(code)
        procedures.append(procedure)
        dates.append(date)
        person_ids.append(person_id)
        crime_categories.append(crime_category)
        location_types.append(location_type)
        latitudes.append(latitude)
        longitudes.append(longitude)
        street_ids.append(street_id)
        street_names.append(street_name)
        contexts.append(context)
        persistent_ids.append(persistent_id)
        crime_ids.append(crime_id)
        location_subtypes.append(location_subtype)
        months.append(month)
    
    #Creating a dataframe and using its vectorizaion properties to assign the remaning columns.
    df_final = pd.DataFrame(codes, columns = ["codes"])
    df_final["procedures"] = procedures
    df_final["dates"] = dates
    df_final["person_ids"] = person_ids
    df_final["crime_categories"] = crime_categories
    df_final["location_types"] = location_types
    df_final["latitudes"] = latitudes
    df_final["longitudes"] = longitudes
    df_final["street_ids"] = street_ids
    df_final["street_names"] = street_names
    df_final["contexts"] = contexts 
    df_final["persistent_ids"] = persistent_ids
    df_final["crime_ids"] = crime_ids
    df_final["location_subtypes"] = location_subtypes
    df_final["months"] = months
    #The Dataframe now holds every single entry of our response.
    
    #Converting the Dataframe to a dictionary:
    dictionary = df_final.to_dict(orient = "index")

    #If the second paramter of the function ("n_records") is equal to "None":
    if n_records == "All":
        
        #Return the all the records in dictionary in a json format.
        return dictionary
    
    
    #Else if the "n_records" is a interger stored as an string and is within the amounts of total records:
    elif int(n_records) in range(len(dictionary)):
        
        #Convert the string into an interger and use it to return the sliced dictionary
        n_record = int(n_records)
        return list(itertools.islice(dictionary.items(), 0, n_record))
    
    #In the case the "n_records" paramter is not "All" or a string stored as an interger that is bigger then then the total amount of records return a suggestion:
    else:
        return '<README>Do Not Panic! Your request has been successful. Unfortunatley the n_records paramter exeeds the amount of records in the dictionary. Try again by using either "All" in your path to retrive all records or inserting the amount of records you want to request.<README>'

# %% [markdown]
# ### 2.1 Below we can visualise the three possible outcomes `get_records`:
# All examples outputs are for a request which is send to the `all_crime_data/<date>/<n_records>` Path.

# %% [markdown]
# **1. Outcome** == User requests all records in the dictionary

# %%
get_records("201811", "All")
# Out:
# {0: {'codes': 'unable-to-prosecute',
#   'procedures': 'Unable to prosecute suspect',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.516165',
#   'longitudes': '-0.102502',
#   'street_ids': 587380,
#   'street_names': 'On or near Green Arbour Court',
#   'contexts': '',
#   'persistent_ids': '18fb11f58eb36c4c914ffda35892d03e52c9f3670dc0c6967131ad83a6897df1',
#   'crime_ids': 69668669,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  1: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.519808',
#   'longitudes': '-0.131669',
#   'street_ids': 960740,
#   'street_names': 'On or near Store Street',
#   'contexts': '',
#   'persistent_ids': '8828bf353c77bc05b360b7a4a2b0f411e660a9eb7d0d86db2663e678e739476f',
#   'crime_ids': 69585340,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  2: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.516028',
#   'longitudes': '-0.138267',
#   'street_ids': 956368,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'f4e394f4283d1fe34fa1c99e903f26c0d372fdff8368050b6cd8ae6b9d97b40b',
#   'crime_ids': 69602072,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-10'},
#  3: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.513096',
#   'longitudes': '-0.132593',
#   'street_ids': 956537,
#   'street_names': 'On or near Bourchier Street',
#   'contexts': '',
#   'persistent_ids': '1a2f4a350884f5e00d6af98be6b8d1068f8949b0d4e05ffa1e0a6bbc96dea835',
#   'crime_ids': 69960067,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  4: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.518080',
#   'longitudes': '-0.126522',
#   'street_ids': 956630,
#   'street_names': 'On or near Great Russell Street',
#   'contexts': '',
#   'persistent_ids': '887bde1afc870869dcd2f951fcc8cb1b18bfe0373de6841140a1e77f39acb2e2',
#   'crime_ids': 69615968,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  5: {'codes': 'imprisoned',
#   'procedures': 'Offender sent to prison',
#   'dates': '2018-11',
#   'person_ids': 1509745.0,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.514487',
#   'longitudes': '-0.135260',
#   'street_ids': 956443,
#   'street_names': 'On or near Wardour Mews',
#   'contexts': '',
#   'persistent_ids': 'de9ee455352e94001562f6bae239c014552fa8c30eaf67ae0c4645c9c5dd98df',
#   'crime_ids': 52758044,
#   'location_subtypes': 'ROAD',
#   'months': '2016-10'},
#  6: {'codes': 'imprisoned',
#   'procedures': 'Offender sent to prison',
#   'dates': '2018-11',
#   'person_ids': 7849410.0,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.512171',
#   'longitudes': '-0.133236',
#   'street_ids': 956437,
#   'street_names': 'On or near Winnett Street',
#   'contexts': '',
#   'persistent_ids': 'f536f21b2f558e9af8cd8ee5dff3db061b834030351a5101523f3ad0b535311b',
#   'crime_ids': 69981686,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  7: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515441',
#   'longitudes': '-0.122321',
#   'street_ids': 956165,
#   'street_names': 'On or near Parker Mews',
#   'contexts': '',
#   'persistent_ids': '442fa9238105bb1ca66e1067706e4bdb768a7fbfa7ffff9a19cab0e0668de856',
#   'crime_ids': 69244848,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  8: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.513664',
#   'longitudes': '-0.131575',
#   'street_ids': 956513,
#   'street_names': 'On or near Frith Street',
#   'contexts': '',
#   'persistent_ids': '115b1a20f7f07d0a1022cddce1db4e9bf41505959a79727e27a1aa55799ae233',
#   'crime_ids': 69634561,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  9: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.507377',
#   'longitudes': '-0.115750',
#   'street_ids': 956289,
#   'street_names': 'On or near A301',
#   'contexts': '',
#   'persistent_ids': 'f4023b771ee6e806907b2c19b40360d9841033c8b867248b6755425b14a0f945',
#   'crime_ids': 69587287,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  10: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.507377',
#   'longitudes': '-0.115750',
#   'street_ids': 956289,
#   'street_names': 'On or near A301',
#   'contexts': '',
#   'persistent_ids': 'f4023b771ee6e806907b2c19b40360d9841033c8b867248b6755425b14a0f945',
#   'crime_ids': 69587287,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  11: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'drugs',
#   'location_types': 'Force',
#   'latitudes': '51.507377',
#   'longitudes': '-0.115750',
#   'street_ids': 956289,
#   'street_names': 'On or near A301',
#   'contexts': '',
#   'persistent_ids': '5e785c310a27a5e3a067548780012eee8097a308581adb9cb5dd014992ab5172',
#   'crime_ids': 69968668,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  12: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.517206',
#   'longitudes': '-0.124166',
#   'street_ids': 956238,
#   'street_names': 'On or near New Oxford Street',
#   'contexts': '',
#   'persistent_ids': 'cb9ac921eb29c40b5e30bf49575835cce0b47e3ee12e6cf504f9ec69ade2787c',
#   'crime_ids': 69628869,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  13: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.513094',
#   'longitudes': '-0.127376',
#   'street_ids': 956587,
#   'street_names': 'On or near Theatre/concert Hall',
#   'contexts': '',
#   'persistent_ids': '6e59baff95a574de204c655ce1eb13664432e1900f6bce9b82591ab3a5d9f447',
#   'crime_ids': 69957579,
#   'location_subtypes': 'THEATRES AND CONCERT HALLS',
#   'months': '2018-11'},
#  14: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.505458',
#   'longitudes': '-0.114389',
#   'street_ids': 956276,
#   'street_names': 'On or near Waterloo Road',
#   'contexts': '',
#   'persistent_ids': '3f1c43be1a5ac6851b3822094787b16a3e9b3ff4c069aa6fc9dae48cd75ab630',
#   'crime_ids': 69936667,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  15: {'codes': 'not-guilty',
#   'procedures': 'Defendant found not guilty',
#   'dates': '2018-11',
#   'person_ids': 11103725.0,
#   'crime_categories': 'drugs',
#   'location_types': 'Force',
#   'latitudes': '51.516733',
#   'longitudes': '-0.104252',
#   'street_ids': 587383,
#   'street_names': 'On or near Supermarket',
#   'contexts': '',
#   'persistent_ids': 'd0645f0d412a61e2befabfb662c3eccb733416b4705145b793516348e6922411',
#   'crime_ids': 68568774,
#   'location_subtypes': 'SUPERMARKET CHAINS',
#   'months': '2018-09'},
#  16: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.517912',
#   'longitudes': '-0.104909',
#   'street_ids': 587571,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': 'a97377a1b4bbc6e851c6e6a069f32f18f68b5a8fb441ca94f8c04e9dc7a1409f',
#   'crime_ids': 69668649,
#   'location_subtypes': 'PARKING',
#   'months': '2018-10'},
#  17: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.518632',
#   'longitudes': '-0.114954',
#   'street_ids': 961047,
#   'street_names': 'On or near Brownlow Street',
#   'contexts': '',
#   'persistent_ids': 'aeee9ad9e65a66d2ff86d9b9f29d805dc6bf211fd5f9ffa79714093b75d9b2eb',
#   'crime_ids': 69625024,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  18: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.506151',
#   'longitudes': '-0.125657',
#   'street_ids': 956298,
#   'street_names': 'On or near Scotland Place',
#   'contexts': '',
#   'persistent_ids': 'f4aaf040cd46ab3e0186e50ff469b95559fd2b36432f497db5ab4612a6c584cb',
#   'crime_ids': 69595395,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  19: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.511868',
#   'longitudes': '-0.138480',
#   'street_ids': 956364,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': '69d6926065531fc605d4669488110f5ed3e41cc657ede33c37e466ec09819af9',
#   'crime_ids': 69613592,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-10'},
#  20: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.519888',
#   'longitudes': '-0.102506',
#   'street_ids': 961277,
#   'street_names': "On or near Greenhill's Rents",
#   'contexts': '',
#   'persistent_ids': '5bfec86d03b6c2e30d91e781235accee26d9b269a26c09df04dbb3bbc4e20c6e',
#   'crime_ids': 69211306,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  21: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.511555',
#   'longitudes': '-0.126199',
#   'street_ids': 956512,
#   'street_names': 'On or near Garrick Street',
#   'contexts': '',
#   'persistent_ids': 'cf739c5ca13381cbb6c693bb6706aca3f18efa7fdaa64c362beaf65d8561980e',
#   'crime_ids': 69621341,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  22: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.502410',
#   'longitudes': '-0.110538',
#   'street_ids': 953486,
#   'street_names': 'On or near Pear Place',
#   'contexts': '',
#   'persistent_ids': 'd697f2c05f78c3738f8a1ee3d37f5fbfbe34a0dce31d00809a7629297b2f00d4',
#   'crime_ids': 69577539,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  23: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.511715',
#   'longitudes': '-0.128902',
#   'street_ids': 956493,
#   'street_names': 'On or near Little Newport Street',
#   'contexts': '',
#   'persistent_ids': '6a9cfcd5b77ca50bd23f8ecc2a447245725bbbcd31bfac13f46fbf39f2f75eed',
#   'crime_ids': 66172331,
#   'location_subtypes': 'ROAD',
#   'months': '2018-06'},
#  24: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.514132',
#   'longitudes': '-0.132723',
#   'street_ids': 956464,
#   'street_names': 'On or near Royalty Mews',
#   'contexts': '',
#   'persistent_ids': '98392c11ba30652953c4faf5ba5d54615fc6ec1ba2223263785cb6ff57c076dd',
#   'crime_ids': 69223517,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  25: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.516698',
#   'longitudes': '-0.135717',
#   'street_ids': 956636,
#   'street_names': 'On or near Berners Place',
#   'contexts': '',
#   'persistent_ids': '27c09d6a451dbb16bf311a2d2f98086f0feb9ede5120017b4cca8b11f53f2953',
#   'crime_ids': 69604378,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  26: {'codes': 'not-guilty',
#   'procedures': 'Defendant found not guilty',
#   'dates': '2018-11',
#   'person_ids': 4114667.0,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.500961',
#   'longitudes': '-0.109330',
#   'street_ids': 953500,
#   'street_names': 'On or near Coral Street',
#   'contexts': '',
#   'persistent_ids': 'f666bfeaacee974df340fee823f5a82a7dabe4f96d0e8a5a1080a0c34b7c5b76',
#   'crime_ids': 61793460,
#   'location_subtypes': 'ROAD',
#   'months': '2017-12'},
#  27: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.504831',
#   'longitudes': '-0.102311',
#   'street_ids': 953744,
#   'street_names': 'On or near Dolben Street',
#   'contexts': '',
#   'persistent_ids': '9c03830b8797c1073dc1321e1181d77a6b0630e9da9b387c8e5176eb9ee5a167',
#   'crime_ids': 67310253,
#   'location_subtypes': 'ROAD',
#   'months': '2018-08'},
#  28: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.507309',
#   'longitudes': '-0.128348',
#   'street_ids': 956645,
#   'street_names': 'On or near Pedestrian Subway',
#   'contexts': '',
#   'persistent_ids': 'c52212db1017bab50964794a76bbf9a5675c5f98a46a6f89efdee6fe3a720874',
#   'crime_ids': 69207702,
#   'location_subtypes': 'SUBWAYS',
#   'months': '2018-09'},
#  29: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.510051',
#   'longitudes': '-0.133971',
#   'street_ids': 956527,
#   'street_names': 'On or near Coventry Street',
#   'contexts': '',
#   'persistent_ids': '5ffe275cb1dc7b6594b405693363f90257d35e81012d0b3efd756a92ffaebcf4',
#   'crime_ids': 69606689,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  30: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.510392',
#   'longitudes': '-0.135023',
#   'street_ids': 956545,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': '27747af7affdead1c5ea2ec463e54b3d5228117b16342a5efd3d18be46c81097',
#   'crime_ids': 69930523,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-11'},
#  31: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.519987',
#   'longitudes': '-0.134487',
#   'street_ids': 960761,
#   'street_names': 'On or near Supermarket',
#   'contexts': '',
#   'persistent_ids': '55c13a970ad54a378581406c8b7a8011a5ae8c6f8d41dc927ba7d6a4ec0156de',
#   'crime_ids': 69930458,
#   'location_subtypes': 'SUPERMARKET CHAINS',
#   'months': '2018-11'},
#  32: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.512098',
#   'longitudes': '-0.139407',
#   'street_ids': 956308,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': '79dbc921a9c20e346bfce71f1f00ebd52ae429321340e6b77789e1548d6e8898',
#   'crime_ids': 69201993,
#   'location_subtypes': 'PARKING',
#   'months': '2018-09'},
#  33: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.518080',
#   'longitudes': '-0.126522',
#   'street_ids': 956630,
#   'street_names': 'On or near Great Russell Street',
#   'contexts': '',
#   'persistent_ids': 'e77b9b421b3ee5026ee463a139bddc9b3dc730638b2c35f0baa4cefa16b83703',
#   'crime_ids': 69971044,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  34: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.500969',
#   'longitudes': '-0.124933',
#   'street_ids': 953533,
#   'street_names': 'On or near Bridge Street',
#   'contexts': '',
#   'persistent_ids': 'aba23fdaa7effa27684caf4311648c3562332697501949a86ff729c2af643422',
#   'crime_ids': 69224355,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  35: {'codes': 'cautioned',
#   'procedures': 'Offender given a caution',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.510827',
#   'longitudes': '-0.130697',
#   'street_ids': 956579,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'b7229512ec4dc32ca5074a00db45ee69255e7cfee0dd9dd2b3f93e279ad1a684',
#   'crime_ids': 69211141,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-09'},
#  36: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.513166',
#   'longitudes': '-0.131336',
#   'street_ids': 956478,
#   'street_names': 'On or near Old Compton Street',
#   'contexts': '',
#   'persistent_ids': '9cd8da0d45bfba5588250d9e779eff773ff3961bc79b617e35d8ea1e536c72b6',
#   'crime_ids': 69209542,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  37: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.519912',
#   'longitudes': '-0.102332',
#   'street_ids': 961284,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'ae7ed89762c93bcc75b9549229b3cc2edfb3369809a56579763e043371699ca4',
#   'crime_ids': 69933544,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-11'},
#  38: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.516506',
#   'longitudes': '-0.131588',
#   'street_ids': 956596,
#   'street_names': 'On or near Supermarket',
#   'contexts': '',
#   'persistent_ids': '17c9f4d6fcc83de41ccf2476c2c20672b882ab6d372e40808b1f90af165b6e81',
#   'crime_ids': 69218152,
#   'location_subtypes': 'SUPERMARKET CHAINS',
#   'months': '2018-09'},
#  39: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.503248',
#   'longitudes': '-0.100042',
#   'street_ids': 953727,
#   'street_names': 'On or near Risborough Street',
#   'contexts': '',
#   'persistent_ids': 'c797b78ffa331beaf3966a6640e6724515e719e1c217344176921ee19fe9e9ff',
#   'crime_ids': 69601346,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  40: {'codes': 'cautioned',
#   'procedures': 'Offender given a caution',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.511922',
#   'longitudes': '-0.096511',
#   'street_ids': 587333,
#   'street_names': 'On or near Queen Victoria Street',
#   'contexts': '',
#   'persistent_ids': '1f6a06d45de303bcf2bf59ac094a7c70b47706b8c8a4b6e255673b83f3d7b02b',
#   'crime_ids': 69668736,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  41: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.517871',
#   'longitudes': '-0.119108',
#   'street_ids': 956231,
#   'street_names': 'On or near Pedestrian Subway',
#   'contexts': '',
#   'persistent_ids': 'db209b59f201d415583409e24bbd1eb82e783136b126b62127e6939b721464dc',
#   'crime_ids': 69630938,
#   'location_subtypes': 'SUBWAYS',
#   'months': '2018-10'},
#  42: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.523357',
#   'longitudes': '-0.124720',
#   'street_ids': 960907,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': 'bdd78ebd141fef01aea21c9668a7efd589d321b79ddd8bafc64ae1082247b817',
#   'crime_ids': 69629090,
#   'location_subtypes': 'PARKING',
#   'months': '2018-10'},
#  43: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.505458',
#   'longitudes': '-0.114389',
#   'street_ids': 956276,
#   'street_names': 'On or near Waterloo Road',
#   'contexts': '',
#   'persistent_ids': '0058fc0957e312732e7235804bf75bb5bc59d1f416df6462cceda83b61a47a12',
#   'crime_ids': 69961901,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  44: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.518709',
#   'longitudes': '-0.101345',
#   'street_ids': 587603,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': '73dc390512326ab1258ab1630e01c1be7575bfa9f1511791687539183eb9f04a',
#   'crime_ids': 67752904,
#   'location_subtypes': 'PARKING',
#   'months': '2018-08'},
#  45: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515739',
#   'longitudes': '-0.100632',
#   'street_ids': 587318,
#   'street_names': 'On or near Warwick Lane',
#   'contexts': '',
#   'persistent_ids': '1a7de67974b5b5b09b42d367b53b101d79a6797c9c459503f1862468d1da5beb',
#   'crime_ids': 69668689,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  46: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.518632',
#   'longitudes': '-0.114954',
#   'street_ids': 961047,
#   'street_names': 'On or near Brownlow Street',
#   'contexts': '',
#   'persistent_ids': 'a8974a554f60c679b9d1c47b3b0cf35bd198c4182ffbe3ccbc667e5e28387b26',
#   'crime_ids': 69261836,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  47: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.515948',
#   'longitudes': '-0.132707',
#   'street_ids': 956456,
#   'street_names': 'On or near Soho Street',
#   'contexts': '',
#   'persistent_ids': '703163ea4cfb26992e94d9a14a98030e432d9df9116c2c7aaaa827658e2d85d1',
#   'crime_ids': 69587829,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  48: {'codes': 'local-resolution',
#   'procedures': 'Local resolution',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'possession-of-weapons',
#   'location_types': 'Force',
#   'latitudes': '51.500969',
#   'longitudes': '-0.124933',
#   'street_ids': 953533,
#   'street_names': 'On or near Bridge Street',
#   'contexts': '',
#   'persistent_ids': 'b157ddad0f9ea657545d9bb0ebeff8cce52079d4ee82a0cb0446cbf1a5b88dba',
#   'crime_ids': 69984042,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  49: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.503137',
#   'longitudes': '-0.113260',
#   'street_ids': 953516,
#   'street_names': 'On or near Police Station',
#   'contexts': '',
#   'persistent_ids': '64758744f3c0f27bf5be87fb44517dbc33a2eeb8dd92f8c2dc48946859138ee2',
#   'crime_ids': 69934878,
#   'location_subtypes': 'POLICE STATIONS',
#   'months': '2018-11'},
#  50: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.503137',
#   'longitudes': '-0.113260',
#   'street_ids': 953516,
#   'street_names': 'On or near Police Station',
#   'contexts': '',
#   'persistent_ids': '64758744f3c0f27bf5be87fb44517dbc33a2eeb8dd92f8c2dc48946859138ee2',
#   'crime_ids': 69934878,
#   'location_subtypes': 'POLICE STATIONS',
#   'months': '2018-11'},
#  51: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515053',
#   'longitudes': '-0.136318',
#   'street_ids': 956480,
#   'street_names': 'On or near Noel Street',
#   'contexts': '',
#   'persistent_ids': 'ec859dc57167de4a74783fe4b1175e7880c091cb2f6f5406dac989961b99137b',
#   'crime_ids': 69982333,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  52: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.497899',
#   'longitudes': '-0.119685',
#   'street_ids': 953525,
#   'street_names': 'On or near Further/higher Educational Building',
#   'contexts': '',
#   'persistent_ids': '557ec89502b3b9babf100862ca012a6c3a7e27ff3620223819a261f1c4fdc123',
#   'crime_ids': 69647075,
#   'location_subtypes': 'HIGHER EDUCATION ESTABLISHMENTS',
#   'months': '2018-10'},
#  53: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.513096',
#   'longitudes': '-0.132593',
#   'street_ids': 956537,
#   'street_names': 'On or near Bourchier Street',
#   'contexts': '',
#   'persistent_ids': '8deebea86b9872355c59421b190bbced0b3e8aa3f02c49159a7a0a18d7a521ff',
#   'crime_ids': 66197910,
#   'location_subtypes': 'ROAD',
#   'months': '2018-06'},
#  54: {'codes': 'local-resolution',
#   'procedures': 'Local resolution',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'drugs',
#   'location_types': 'Force',
#   'latitudes': '51.513180',
#   'longitudes': '-0.127156',
#   'street_ids': 956444,
#   'street_names': "On or near Upper St Martin's Lane",
#   'contexts': '',
#   'persistent_ids': '5729b63640bd610dcad59f6e95fe24eebfb4ae3502ce78a69ca11e4f9f959bb1',
#   'crime_ids': 69968338,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  55: {'codes': 'suspended-sentence',
#   'procedures': 'Offender given suspended prison sentence',
#   'dates': '2018-11',
#   'person_ids': 6196204.0,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515053',
#   'longitudes': '-0.136318',
#   'street_ids': 956480,
#   'street_names': 'On or near Noel Street',
#   'contexts': '',
#   'persistent_ids': 'ec859dc57167de4a74783fe4b1175e7880c091cb2f6f5406dac989961b99137b',
#   'crime_ids': 69982333,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  56: {'codes': 'further-investigation-not-in-public-interest',
#   'procedures': 'Further investigation is not in the public interest',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515173',
#   'longitudes': '-0.108453',
#   'street_ids': 587556,
#   'street_names': 'On or near Pemberton Row',
#   'contexts': '',
#   'persistent_ids': 'dd80f630e4f37591426840a83681e8ce27095d1ff87fd4f32d6ce898d50960b9',
#   'crime_ids': 69668615,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  57: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.497426',
#   'longitudes': '-0.112602',
#   'street_ids': 953440,
#   'street_names': 'On or near Mcauley Close',
#   'contexts': '',
#   'persistent_ids': '26728c9ac1d8144d3ea29f97fac02798f6a5e6dd48573c31669a764992e56039',
#   'crime_ids': 69941082,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  58: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.522071',
#   'longitudes': '-0.119670',
#   'street_ids': 960958,
#   'street_names': 'On or near Great Ormond Street',
#   'contexts': '',
#   'persistent_ids': '73cbc3b5adccc7a9611c1e5ccc162e8198d8121418612e69a05c5765edb93dc3',
#   'crime_ids': 69628503,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  59: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.518635',
#   'longitudes': '-0.132020',
#   'street_ids': 960756,
#   'street_names': 'On or near Bayley Street',
#   'contexts': '',
#   'persistent_ids': 'be18f99ae67032f9fcdf7074aa8f0970bdc408188345c8374b4481b780b69733',
#   'crime_ids': 69934858,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  60: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.516506',
#   'longitudes': '-0.131588',
#   'street_ids': 956596,
#   'street_names': 'On or near Supermarket',
#   'contexts': '',
#   'persistent_ids': 'f15e65d4392e8a6306b23ec2a7522b0f07ce0e2e7dbceaf7f21a8068890646d3',
#   'crime_ids': 69938989,
#   'location_subtypes': 'SUPERMARKET CHAINS',
#   'months': '2018-11'},
#  61: {'codes': 'unable-to-prosecute',
#   'procedures': 'Unable to prosecute suspect',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.512117',
#   'longitudes': '-0.102411',
#   'street_ids': 587332,
#   'street_names': 'On or near Queen Victoria Street',
#   'contexts': '',
#   'persistent_ids': '38db346bda7cca236914b86632d19a25a2b85283fb2a2a0488a131ec82432c08',
#   'crime_ids': 69668674,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  62: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.516096',
#   'longitudes': '-0.138610',
#   'street_ids': 956309,
#   'street_names': 'On or near Winsley Street',
#   'contexts': '',
#   'persistent_ids': '052698ef5698f9aa2d09ad42dfc250a0957e4f069a791e1be78921217ddb3695',
#   'crime_ids': 69936733,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  63: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.512165',
#   'longitudes': '-0.123825',
#   'street_ids': 956143,
#   'street_names': 'On or near Shopping Area',
#   'contexts': '',
#   'persistent_ids': '98a9dd0372614af9e82f916ac702002b3745d4f3f20560016fd7c62431640c24',
#   'crime_ids': 69591158,
#   'location_subtypes': 'MARKETS',
#   'months': '2018-10'},
#  64: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515441',
#   'longitudes': '-0.122321',
#   'street_ids': 956165,
#   'street_names': 'On or near Parker Mews',
#   'contexts': '',
#   'persistent_ids': 'ab90798a25c0ac098e1a39f0fbcecbbcfcf42a841c3efd9dfaba6982bc63d1a6',
#   'crime_ids': 69988817,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  65: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.513158',
#   'longitudes': '-0.129722',
#   'street_ids': 956593,
#   'street_names': 'On or near Theatre/concert Hall',
#   'contexts': '',
#   'persistent_ids': '30732413b497e74737674a2c225c1c023f21c54e80671c20808777deb264a6bc',
#   'crime_ids': 69628143,
#   'location_subtypes': 'THEATRES AND CONCERT HALLS',
#   'months': '2018-10'},
#  66: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.502820',
#   'longitudes': '-0.119267',
#   'street_ids': 953537,
#   'street_names': 'On or near Theme/adventure Park',
#   'contexts': '',
#   'persistent_ids': '691ce73a459253a9704b7dbe83f79b591318b7a7b82cae3cd2fc47994056d409',
#   'crime_ids': 69609193,
#   'location_subtypes': 'THEME AND ADVENTURE PARKS',
#   'months': '2018-10'},
#  67: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.512984',
#   'longitudes': '-0.130680',
#   'street_ids': 956466,
#   'street_names': 'On or near Romilly Street',
#   'contexts': '',
#   'persistent_ids': '6a51db0c845780b667dcc6a8c2c71e6a185a1220469189f79077ab6d5060553d',
#   'crime_ids': 69615928,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  68: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.516365',
#   'longitudes': '-0.133439',
#   'street_ids': 956606,
#   'street_names': 'On or near Theme/adventure Park',
#   'contexts': '',
#   'persistent_ids': '3b27da24692cdc418b54312d20030051437af0792009c34ce86adec03e16db57',
#   'crime_ids': 69628047,
#   'location_subtypes': 'THEME AND ADVENTURE PARKS',
#   'months': '2018-10'},
#  69: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.516365',
#   'longitudes': '-0.133439',
#   'street_ids': 956606,
#   'street_names': 'On or near Theme/adventure Park',
#   'contexts': '',
#   'persistent_ids': '3b27da24692cdc418b54312d20030051437af0792009c34ce86adec03e16db57',
#   'crime_ids': 69628047,
#   'location_subtypes': 'THEME AND ADVENTURE PARKS',
#   'months': '2018-10'},
#  70: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.510835',
#   'longitudes': '-0.128996',
#   'street_ids': 956562,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': '3dffa329b0c12ed6cf2ea01ef3c06cbb297a3da2432a1978e8ea3048dfea09b9',
#   'crime_ids': 69953042,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-11'},
#  71: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.512171',
#   'longitudes': '-0.133236',
#   'street_ids': 956437,
#   'street_names': 'On or near Winnett Street',
#   'contexts': '',
#   'persistent_ids': 'e6f4502b850044ef4a294c8ec2869458f1ade626716f1d47a7c3ab4df159fcd5',
#   'crime_ids': 69631117,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  72: {'codes': 'unable-to-proceed',
#   'procedures': 'Court case unable to proceed',
#   'dates': '2018-11',
#   'person_ids': 3124628.0,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.511465',
#   'longitudes': '-0.139750',
#   'street_ids': 956327,
#   'street_names': 'On or near New Burlington Mews',
#   'contexts': '',
#   'persistent_ids': '8ced698a5e51cff921f47d0f72c2e9d1898205ce2b6ab3072a1ed619709b3536',
#   'crime_ids': 66698292,
#   'location_subtypes': 'ROAD',
#   'months': '2018-07'},
#  73: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.513928',
#   'longitudes': '-0.108231',
#   'street_ids': 587555,
#   'street_names': 'On or near Pleydell Street',
#   'contexts': '',
#   'persistent_ids': 'a523797c2a6bb41813634525a0220d2fcd145466333d5cd920ca99b0dead3578',
#   'crime_ids': 70163687,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  74: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.512749',
#   'longitudes': '-0.104244',
#   'street_ids': 587340,
#   'street_names': 'On or near New Bridge Street',
#   'contexts': '',
#   'persistent_ids': '2802e65c102a50dbb47c0b6e48da8a5e26630524702f985f24c993a712ad4def',
#   'crime_ids': 70163714,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  75: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.514746',
#   'longitudes': '-0.130637',
#   'street_ids': 956489,
#   'street_names': 'On or near Manette Street',
#   'contexts': '',
#   'persistent_ids': 'b754bec90717977d1b350eaad4adf1465287382dbc696ae1c9ad66cc41ea4418',
#   'crime_ids': 69594653,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  76: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.499253',
#   'longitudes': '-0.103219',
#   'street_ids': 953732,
#   'street_names': 'On or near Milcote Street',
#   'contexts': '',
#   'persistent_ids': '0f32d09497f38a09894681a6a54b87ca77143fb680a56a20e067dea9e0618752',
#   'crime_ids': 66180373,
#   'location_subtypes': 'ROAD',
#   'months': '2018-06'},
#  77: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.508060',
#   'longitudes': '-0.106788',
#   'street_ids': 956252,
#   'street_names': 'On or near Upper Ground',
#   'contexts': '',
#   'persistent_ids': '534fb212d5b744f2996cb70e3f6613ad4e2ad106a8d584b2f8f85059b8b57b24',
#   'crime_ids': 63331641,
#   'location_subtypes': 'ROAD',
#   'months': '2018-02'},
#  78: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.511555',
#   'longitudes': '-0.126199',
#   'street_ids': 956512,
#   'street_names': 'On or near Garrick Street',
#   'contexts': '',
#   'persistent_ids': '9deea1389cdf938e1ca7ce2749fab55c7429bf744f9cf06b749d8c45fccb0dc9',
#   'crime_ids': 69604018,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  79: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.516341',
#   'longitudes': '-0.120151',
#   'street_ids': 956218,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'b1c5a292752456ef512faa7f40057cb18aa256d1d6b07590be0915944c94b0ea',
#   'crime_ids': 69597177,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-10'},
#  80: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.502369',
#   'longitudes': '-0.102975',
#   'street_ids': 953718,
#   'street_names': 'On or near Surrey Row',
#   'contexts': '',
#   'persistent_ids': 'ce756180ddbeb82e9c1b3154ea5fe832102aae8eda8621f831c22c02e6a55a55',
#   'crime_ids': 69216812,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  81: {'codes': 'unable-to-proceed',
#   'procedures': 'Court case unable to proceed',
#   'dates': '2018-11',
#   'person_ids': 757279.0,
#   'crime_categories': 'criminal-damage-arson',
#   'location_types': 'Force',
#   'latitudes': '51.500808',
#   'longitudes': '-0.130646',
#   'street_ids': 953309,
#   'street_names': 'On or near Old Queen Street',
#   'contexts': '',
#   'persistent_ids': 'a6dc9d44f7c17e30c08388a2e986137e99ef25a2dec3d11ed2b88b672bd943d5',
#   'crime_ids': 66156471,
#   'location_subtypes': 'ROAD',
#   'months': '2018-06'},
#  82: {'codes': 'unable-to-proceed',
#   'procedures': 'Court case unable to proceed',
#   'dates': '2018-11',
#   'person_ids': 10887514.0,
#   'crime_categories': 'criminal-damage-arson',
#   'location_types': 'Force',
#   'latitudes': '51.500808',
#   'longitudes': '-0.130646',
#   'street_ids': 953309,
#   'street_names': 'On or near Old Queen Street',
#   'contexts': '',
#   'persistent_ids': 'a6dc9d44f7c17e30c08388a2e986137e99ef25a2dec3d11ed2b88b672bd943d5',
#   'crime_ids': 66156471,
#   'location_subtypes': 'ROAD',
#   'months': '2018-06'},
#  83: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.517728',
#   'longitudes': '-0.102380',
#   'street_ids': 587379,
#   'street_names': 'On or near Hosier Lane',
#   'contexts': '',
#   'persistent_ids': '75d8c9ebea7ed54155099bca19f666437ce3b1ecf2ee7f63db0ce70d055e2949',
#   'crime_ids': 68568780,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  84: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.511067',
#   'longitudes': '-0.123798',
#   'street_ids': 956180,
#   'street_names': 'On or near Henrietta Street',
#   'contexts': '',
#   'persistent_ids': 'd09335a4bbb93b3facefb09e0fcb26456599c650cf813ff3ea18949c364c2bb5',
#   'crime_ids': 69928486,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  85: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.507339',
#   'longitudes': '-0.108388',
#   'street_ids': 956287,
#   'street_names': 'On or near Broadwall',
#   'contexts': '',
#   'persistent_ids': '648383d9deb9fcdfe3ba26a41c6b69dd9a975367722b8562d909bccfd898a942',
#   'crime_ids': 69627748,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  86: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.507339',
#   'longitudes': '-0.108388',
#   'street_ids': 956287,
#   'street_names': 'On or near Broadwall',
#   'contexts': '',
#   'persistent_ids': '648383d9deb9fcdfe3ba26a41c6b69dd9a975367722b8562d909bccfd898a942',
#   'crime_ids': 69627748,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  87: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'drugs',
#   'location_types': 'Force',
#   'latitudes': '51.516506',
#   'longitudes': '-0.131588',
#   'street_ids': 956596,
#   'street_names': 'On or near Supermarket',
#   'contexts': '',
#   'persistent_ids': '6627796344a8eb789043400aac19cdc49caaca5c27ca961d9c94f07e762ebfed',
#   'crime_ids': 69227155,
#   'location_subtypes': 'SUPERMARKET CHAINS',
#   'months': '2018-09'},
#  88: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.509838',
#   'longitudes': '-0.124512',
#   'street_ids': 956202,
#   'street_names': 'On or near Agar Street',
#   'contexts': '',
#   'persistent_ids': 'a9886a107f3b7b4e9fc3db9a7d7ee68ddbbe4280848cb223e8df6c37e7502267',
#   'crime_ids': 69594830,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  89: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.513338',
#   'longitudes': '-0.133649',
#   'street_ids': 956573,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'c143d95c6e1d4d61bd378fb1ecc0ea67f232a069aa135b7ab20d9558d9b43ab7',
#   'crime_ids': 69594928,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-10'},
#  90: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.509554',
#   'longitudes': '-0.138343',
#   'street_ids': 956316,
#   'street_names': 'On or near Sackville Street',
#   'contexts': '',
#   'persistent_ids': '2f7c266af2f6bc82f3e5b5473cf3d186c60a9da3a44b54474440990d791d96c6',
#   'crime_ids': 69581369,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  91: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.509554',
# ...
#   'persistent_ids': '4af0f7a59b6c8fa59c882c5a13e1109af153159f22e587572f70565070649489',
#   'crime_ids': 69939959,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  970: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.514377',
#   'longitudes': '-0.129499',
#   'street_ids': 956565,
#   'street_names': 'On or near Theatre/concert Hall',
#   'contexts': '',
#   'persistent_ids': '554107d02de50cc6303084aa4e722daebb4f24a4c4f801ce904e4390b32754cc',
#   'crime_ids': 69928434,
#   'location_subtypes': 'THEATRES AND CONCERT HALLS',
#   'months': '2018-11'},
#  971: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.511922',
#   'longitudes': '-0.096511',
#   'street_ids': 587333,
#   'street_names': 'On or near Queen Victoria Street',
#   'contexts': '',
#   'persistent_ids': 'f96f040e750b71b7ca23969d6112b6a1cdaff1b6fe045e79c9d6f4161bedb313',
#   'crime_ids': 70163806,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  972: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.512289',
#   'longitudes': '-0.137814',
#   'street_ids': 956354,
#   'street_names': 'On or near Beak Street',
#   'contexts': '',
#   'persistent_ids': '155072af92124e85554f60a0fcc09ead955176a981224fb8c5110d9a82d1a41f',
#   'crime_ids': 69637635,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  973: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.506417',
#   'longitudes': '-0.136713',
#   'street_ids': 956662,
#   'street_names': 'On or near Cleveland Place',
#   'contexts': '',
#   'persistent_ids': 'cd2b995cd228f54e8025e75a229e294cf30275feb7ce4dda99e4ae130b3b000d',
#   'crime_ids': 66701152,
#   'location_subtypes': 'ROAD',
#   'months': '2018-07'},
#  974: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.512108',
#   'longitudes': '-0.119735',
#   'street_ids': 956216,
#   'street_names': 'On or near Theatre/concert Hall',
#   'contexts': '',
#   'persistent_ids': 'b83b96e1f5fd86239c0f03aa396dee1dae26414f21293492c2044b44ae989e40',
#   'crime_ids': 69646166,
#   'location_subtypes': 'THEATRES AND CONCERT HALLS',
#   'months': '2018-10'},
#  975: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.509980',
#   'longitudes': '-0.132331',
#   'street_ids': 956543,
#   'street_names': 'On or near Motorway Service Area',
#   'contexts': '',
#   'persistent_ids': '9f97d02a0672ff9d05a15b9e15056a804b703835e89ded207b6670835fe31c7f',
#   'crime_ids': 69234325,
#   'location_subtypes': 'MOTORWAY SERVICE STATIONS',
#   'months': '2018-09'},
#  976: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.500237',
#   'longitudes': '-0.132023',
#   'street_ids': 953312,
#   'street_names': 'On or near Dartmouth Street',
#   'contexts': '',
#   'persistent_ids': '1331a4efb76674d3337460b50f7b01f8a62abe95a4960e8518625a58a87ec3fa',
#   'crime_ids': 69938371,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  977: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.519888',
#   'longitudes': '-0.102506',
#   'street_ids': 961277,
#   'street_names': "On or near Greenhill's Rents",
#   'contexts': '',
#   'persistent_ids': '3fbfba0db00b68c01d1823fed0d2cfa01ed2a885cb1831bd497c31a230b73a52',
#   'crime_ids': 69984862,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  978: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.501816',
#   'longitudes': '-0.099943',
#   'street_ids': 953753,
#   'street_names': 'On or near Sports/recreation Area',
#   'contexts': '',
#   'persistent_ids': 'bf8bf2f5f4617677b97e2350a2171b192e700b57f1c272bfe2edcd988e71107b',
#   'crime_ids': 69598687,
#   'location_subtypes': 'SPORTS GROUNDS, STADIA AND PITCHES',
#   'months': '2018-10'},
#  979: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.502791',
#   'longitudes': '-0.116905',
#   'street_ids': 953521,
#   'street_names': 'On or near Chicheley Street',
#   'contexts': '',
#   'persistent_ids': 'd82a5fc329ccb6b8007fae0b9b70ab68cb0ea7630e617382496d66a3f13b1e34',
#   'crime_ids': 69579624,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  980: {'codes': 'compensation',
#   'procedures': 'Offender ordered to pay compensation',
#   'dates': '2018-11',
#   'person_ids': 11136047.0,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.519888',
#   'longitudes': '-0.102506',
#   'street_ids': 961277,
#   'street_names': "On or near Greenhill's Rents",
#   'contexts': '',
#   'persistent_ids': '3fbfba0db00b68c01d1823fed0d2cfa01ed2a885cb1831bd497c31a230b73a52',
#   'crime_ids': 69984862,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  981: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'shoplifting',
#   'location_types': 'Force',
#   'latitudes': '51.515050',
#   'longitudes': '-0.127108',
#   'street_ids': 956712,
#   'street_names': 'On or near Shaftesbury Avenue',
#   'contexts': '',
#   'persistent_ids': '54d87d580dc398bd1624050ad57d36a2974d79ecd6898718e7052753dead3a5f',
#   'crime_ids': 67290295,
#   'location_subtypes': 'ROAD',
#   'months': '2018-08'},
#  982: {'codes': 'cautioned',
#   'procedures': 'Offender given a caution',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.498685',
#   'longitudes': '-0.115994',
#   'street_ids': 923901,
#   'street_names': 'On or near Royal Street',
#   'contexts': '',
#   'persistent_ids': '8aefdc74b1ce610c8706b4e598c66c5cf86747a6488d6639ebbb3bae6b3b44e8',
#   'crime_ids': 69637223,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  983: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.511040',
#   'longitudes': '-0.113726',
#   'street_ids': 956267,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': 'bbe3880c7b7f641ec0b18ea90858d4f9a87291bd145e8843a37b8cb2cb8d12aa',
#   'crime_ids': 69208923,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-09'},
#  984: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.514527',
#   'longitudes': '-0.140057',
#   'street_ids': 956360,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': '26032eecb990e99b0230f0f46dbe67f1a6f53fb9da75bc917345026b15ef600c',
#   'crime_ids': 69221665,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-09'},
#  985: {'codes': 'suspended-sentence',
#   'procedures': 'Offender given suspended prison sentence',
#   'dates': '2018-11',
#   'person_ids': 9343341.0,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.510715',
#   'longitudes': '-0.125960',
#   'street_ids': 956500,
#   'street_names': 'On or near Hop Gardens',
#   'contexts': '',
#   'persistent_ids': '5e310fc931080678895d0f46c748ca6bf2931643aeed7f4c956be6d0ebe6d968',
#   'crime_ids': 69605505,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  986: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'burglary',
#   'location_types': 'Force',
#   'latitudes': '51.513928',
#   'longitudes': '-0.108231',
#   'street_ids': 587555,
#   'street_names': 'On or near Pleydell Street',
#   'contexts': '',
#   'persistent_ids': '2fdee194a96d390b49286f4536d165840a1f12f1b25edb9301a47f776661ee29',
#   'crime_ids': 67752061,
#   'location_subtypes': 'ROAD',
#   'months': '2018-07'},
#  987: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.519888',
#   'longitudes': '-0.102506',
#   'street_ids': 961277,
#   'street_names': "On or near Greenhill's Rents",
#   'contexts': '',
#   'persistent_ids': 'd30ff1f9a91f06c11be950d7f42ecf3bab28d02e72cbb9d00b49ded1ef8437c2',
#   'crime_ids': 69625348,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  988: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.515453',
#   'longitudes': '-0.134932',
#   'street_ids': 956501,
#   'street_names': 'On or near Hollen Street',
#   'contexts': '',
#   'persistent_ids': 'f3aff0ceae33f1badae97577980b54d6d3ee50882de408bdae122b1de1d5cf35',
#   'crime_ids': 69217026,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  989: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.518709',
#   'longitudes': '-0.101345',
#   'street_ids': 587603,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': 'f5b4274b016d8199d1af7efcc09a9d76a95cab44c4d0897e47578d370a954c86',
#   'crime_ids': 67752136,
#   'location_subtypes': 'PARKING',
#   'months': '2018-07'},
#  990: {'codes': 'awaiting-court-result',
#   'procedures': 'Awaiting court outcome',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.515404',
#   'longitudes': '-0.102721',
#   'street_ids': 587329,
#   'street_names': "On or near St Georges's Court",
#   'contexts': '',
#   'persistent_ids': 'd938ca4c60d572c7eb2bfde39190cce84f51316bd867e661aa3b2d01849a8492',
#   'crime_ids': 67752885,
#   'location_subtypes': 'ROAD',
#   'months': '2018-08'},
#  991: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.516824',
#   'longitudes': '-0.113256',
#   'street_ids': 956270,
#   'street_names': 'On or near Old Square',
#   'contexts': '',
#   'persistent_ids': '11b6f63fa4884c2ce0968e0c02f503c593df6d61ac6d726cdda22426759ac866',
#   'crime_ids': 69198124,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  992: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'violent-crime',
#   'location_types': 'Force',
#   'latitudes': '51.517909',
#   'longitudes': '-0.109709',
#   'street_ids': 587581,
#   'street_names': 'On or near High Holborn',
#   'contexts': '',
#   'persistent_ids': '5f4503f137b2cfcd88ed384ace2f2cd7b67fed973104ec8e718b821163dc0154',
#   'crime_ids': 69577299,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  993: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.514007',
#   'longitudes': '-0.131085',
#   'street_ids': 956581,
#   'street_names': 'On or near Nightclub',
#   'contexts': '',
#   'persistent_ids': '01ae57be7c46bfabfd007e932889f4554947d9358f1448d084afa8d50556649b',
#   'crime_ids': 69945156,
#   'location_subtypes': 'NIGHTCLUBS',
#   'months': '2018-11'},
#  994: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'theft-from-the-person',
#   'location_types': 'Force',
#   'latitudes': '51.499572',
#   'longitudes': '-0.106823',
#   'street_ids': 953472,
#   'street_names': 'On or near Waterloo Road',
#   'contexts': '',
#   'persistent_ids': '0ce32298d6d6da2e344ea1458bb29c114e5db85f92a19ba13cf4f2b60d992d40',
#   'crime_ids': 69983236,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  995: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.505179',
#   'longitudes': '-0.106547',
#   'street_ids': 956283,
#   'street_names': 'On or near Hatfields',
#   'contexts': '',
#   'persistent_ids': 'a86f1fb43869384937a0bf86d0cfd855f0c55c5f7fd8100886416d229889c484',
#   'crime_ids': 69576683,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  996: {'codes': 'imprisoned',
#   'procedures': 'Offender sent to prison',
#   'dates': '2018-11',
#   'person_ids': 3107285.0,
#   'crime_categories': 'public-order',
#   'location_types': 'Force',
#   'latitudes': '51.516966',
#   'longitudes': '-0.105900',
#   'street_ids': 587577,
#   'street_names': 'On or near Plumtree Court',
#   'contexts': '',
#   'persistent_ids': 'f1d246b89ad6467e7e301a85f5662e2c717e74b24f618a5b717b7d69134e0f0b',
#   'crime_ids': 70163693,
#   'location_subtypes': 'ROAD',
#   'months': '2018-11'},
#  997: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'vehicle-crime',
#   'location_types': 'Force',
#   'latitudes': '51.518709',
#   'longitudes': '-0.101345',
#   'street_ids': 587603,
#   'street_names': 'On or near Parking Area',
#   'contexts': '',
#   'persistent_ids': '36815a04fd3e2fecde26fc4969a0a756ab50c6836c566364ad21091e629ed262',
#   'crime_ids': 69668676,
#   'location_subtypes': 'PARKING',
#   'months': '2018-10'},
#  998: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'other-theft',
#   'location_types': 'Force',
#   'latitudes': '51.510893',
#   'longitudes': '-0.120231',
#   'street_ids': 956150,
#   'street_names': 'On or near Strand',
#   'contexts': '',
#   'persistent_ids': 'e8bee7edce422c2c9ff5f1d357570959718a6a6b9f3cf15ea37e86643dc6cae2',
#   'crime_ids': 69229360,
#   'location_subtypes': 'ROAD',
#   'months': '2018-09'},
#  999: {'codes': 'no-further-action',
#   'procedures': 'Investigation complete; no suspect identified',
#   'dates': '2018-11',
#   'person_ids': nan,
#   'crime_categories': 'robbery',
#   'location_types': 'Force',
#   'latitudes': '51.519702',
#   'longitudes': '-0.117202',
#   'street_ids': 961006,
#   'street_names': 'On or near Princeton Street',
#   'contexts': '',
#   'persistent_ids': 'c000457786901cf60688112faf0df889d00c8b1913eba78c46985369deeda3fe',
#   'crime_ids': 69586634,
#   'location_subtypes': 'ROAD',
#   'months': '2018-10'},
#  ...}

# %% [markdown]
# **2. Outcome** == User requests a specific amount of records which is **smaller** than the total amount of records in the dictionary:

# %%
get_records("201811", "50")
# Out:
# [(0,
#   {'codes': 'unable-to-prosecute',
#    'procedures': 'Unable to prosecute suspect',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.516165',
#    'longitudes': '-0.102502',
#    'street_ids': 587380,
#    'street_names': 'On or near Green Arbour Court',
#    'contexts': '',
#    'persistent_ids': '18fb11f58eb36c4c914ffda35892d03e52c9f3670dc0c6967131ad83a6897df1',
#    'crime_ids': 69668669,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (1,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.519808',
#    'longitudes': '-0.131669',
#    'street_ids': 960740,
#    'street_names': 'On or near Store Street',
#    'contexts': '',
#    'persistent_ids': '8828bf353c77bc05b360b7a4a2b0f411e660a9eb7d0d86db2663e678e739476f',
#    'crime_ids': 69585340,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (2,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'robbery',
#    'location_types': 'Force',
#    'latitudes': '51.516028',
#    'longitudes': '-0.138267',
#    'street_ids': 956368,
#    'street_names': 'On or near Nightclub',
#    'contexts': '',
#    'persistent_ids': 'f4e394f4283d1fe34fa1c99e903f26c0d372fdff8368050b6cd8ae6b9d97b40b',
#    'crime_ids': 69602072,
#    'location_subtypes': 'NIGHTCLUBS',
#    'months': '2018-10'}),
#  (3,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.513096',
#    'longitudes': '-0.132593',
#    'street_ids': 956537,
#    'street_names': 'On or near Bourchier Street',
#    'contexts': '',
#    'persistent_ids': '1a2f4a350884f5e00d6af98be6b8d1068f8949b0d4e05ffa1e0a6bbc96dea835',
#    'crime_ids': 69960067,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (4,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'theft-from-the-person',
#    'location_types': 'Force',
#    'latitudes': '51.518080',
#    'longitudes': '-0.126522',
#    'street_ids': 956630,
#    'street_names': 'On or near Great Russell Street',
#    'contexts': '',
#    'persistent_ids': '887bde1afc870869dcd2f951fcc8cb1b18bfe0373de6841140a1e77f39acb2e2',
#    'crime_ids': 69615968,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (5,
#   {'codes': 'imprisoned',
#    'procedures': 'Offender sent to prison',
#    'dates': '2018-11',
#    'person_ids': 1509745.0,
#    'crime_categories': 'burglary',
#    'location_types': 'Force',
#    'latitudes': '51.514487',
#    'longitudes': '-0.135260',
#    'street_ids': 956443,
#    'street_names': 'On or near Wardour Mews',
#    'contexts': '',
#    'persistent_ids': 'de9ee455352e94001562f6bae239c014552fa8c30eaf67ae0c4645c9c5dd98df',
#    'crime_ids': 52758044,
#    'location_subtypes': 'ROAD',
#    'months': '2016-10'}),
#  (6,
#   {'codes': 'imprisoned',
#    'procedures': 'Offender sent to prison',
#    'dates': '2018-11',
#    'person_ids': 7849410.0,
#    'crime_categories': 'theft-from-the-person',
#    'location_types': 'Force',
#    'latitudes': '51.512171',
#    'longitudes': '-0.133236',
#    'street_ids': 956437,
#    'street_names': 'On or near Winnett Street',
#    'contexts': '',
#    'persistent_ids': 'f536f21b2f558e9af8cd8ee5dff3db061b834030351a5101523f3ad0b535311b',
#    'crime_ids': 69981686,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (7,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.515441',
#    'longitudes': '-0.122321',
#    'street_ids': 956165,
#    'street_names': 'On or near Parker Mews',
#    'contexts': '',
#    'persistent_ids': '442fa9238105bb1ca66e1067706e4bdb768a7fbfa7ffff9a19cab0e0668de856',
#    'crime_ids': 69244848,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (8,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.513664',
#    'longitudes': '-0.131575',
#    'street_ids': 956513,
#    'street_names': 'On or near Frith Street',
#    'contexts': '',
#    'persistent_ids': '115b1a20f7f07d0a1022cddce1db4e9bf41505959a79727e27a1aa55799ae233',
#    'crime_ids': 69634561,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (9,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.507377',
#    'longitudes': '-0.115750',
#    'street_ids': 956289,
#    'street_names': 'On or near A301',
#    'contexts': '',
#    'persistent_ids': 'f4023b771ee6e806907b2c19b40360d9841033c8b867248b6755425b14a0f945',
#    'crime_ids': 69587287,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (10,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.507377',
#    'longitudes': '-0.115750',
#    'street_ids': 956289,
#    'street_names': 'On or near A301',
#    'contexts': '',
#    'persistent_ids': 'f4023b771ee6e806907b2c19b40360d9841033c8b867248b6755425b14a0f945',
#    'crime_ids': 69587287,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (11,
#   {'codes': 'awaiting-court-result',
#    'procedures': 'Awaiting court outcome',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'drugs',
#    'location_types': 'Force',
#    'latitudes': '51.507377',
#    'longitudes': '-0.115750',
#    'street_ids': 956289,
#    'street_names': 'On or near A301',
#    'contexts': '',
#    'persistent_ids': '5e785c310a27a5e3a067548780012eee8097a308581adb9cb5dd014992ab5172',
#    'crime_ids': 69968668,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (12,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'public-order',
#    'location_types': 'Force',
#    'latitudes': '51.517206',
#    'longitudes': '-0.124166',
#    'street_ids': 956238,
#    'street_names': 'On or near New Oxford Street',
#    'contexts': '',
#    'persistent_ids': 'cb9ac921eb29c40b5e30bf49575835cce0b47e3ee12e6cf504f9ec69ade2787c',
#    'crime_ids': 69628869,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (13,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'public-order',
#    'location_types': 'Force',
#    'latitudes': '51.513094',
#    'longitudes': '-0.127376',
#    'street_ids': 956587,
#    'street_names': 'On or near Theatre/concert Hall',
#    'contexts': '',
#    'persistent_ids': '6e59baff95a574de204c655ce1eb13664432e1900f6bce9b82591ab3a5d9f447',
#    'crime_ids': 69957579,
#    'location_subtypes': 'THEATRES AND CONCERT HALLS',
#    'months': '2018-11'}),
#  (14,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.505458',
#    'longitudes': '-0.114389',
#    'street_ids': 956276,
#    'street_names': 'On or near Waterloo Road',
#    'contexts': '',
#    'persistent_ids': '3f1c43be1a5ac6851b3822094787b16a3e9b3ff4c069aa6fc9dae48cd75ab630',
#    'crime_ids': 69936667,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (15,
#   {'codes': 'not-guilty',
#    'procedures': 'Defendant found not guilty',
#    'dates': '2018-11',
#    'person_ids': 11103725.0,
#    'crime_categories': 'drugs',
#    'location_types': 'Force',
#    'latitudes': '51.516733',
#    'longitudes': '-0.104252',
#    'street_ids': 587383,
#    'street_names': 'On or near Supermarket',
#    'contexts': '',
#    'persistent_ids': 'd0645f0d412a61e2befabfb662c3eccb733416b4705145b793516348e6922411',
#    'crime_ids': 68568774,
#    'location_subtypes': 'SUPERMARKET CHAINS',
#    'months': '2018-09'}),
#  (16,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.517912',
#    'longitudes': '-0.104909',
#    'street_ids': 587571,
#    'street_names': 'On or near Parking Area',
#    'contexts': '',
#    'persistent_ids': 'a97377a1b4bbc6e851c6e6a069f32f18f68b5a8fb441ca94f8c04e9dc7a1409f',
#    'crime_ids': 69668649,
#    'location_subtypes': 'PARKING',
#    'months': '2018-10'}),
#  (17,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'vehicle-crime',
#    'location_types': 'Force',
#    'latitudes': '51.518632',
#    'longitudes': '-0.114954',
#    'street_ids': 961047,
#    'street_names': 'On or near Brownlow Street',
#    'contexts': '',
#    'persistent_ids': 'aeee9ad9e65a66d2ff86d9b9f29d805dc6bf211fd5f9ffa79714093b75d9b2eb',
#    'crime_ids': 69625024,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (18,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'robbery',
#    'location_types': 'Force',
#    'latitudes': '51.506151',
#    'longitudes': '-0.125657',
#    'street_ids': 956298,
#    'street_names': 'On or near Scotland Place',
#    'contexts': '',
#    'persistent_ids': 'f4aaf040cd46ab3e0186e50ff469b95559fd2b36432f497db5ab4612a6c584cb',
#    'crime_ids': 69595395,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (19,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.511868',
#    'longitudes': '-0.138480',
#    'street_ids': 956364,
#    'street_names': 'On or near Nightclub',
#    'contexts': '',
#    'persistent_ids': '69d6926065531fc605d4669488110f5ed3e41cc657ede33c37e466ec09819af9',
#    'crime_ids': 69613592,
#    'location_subtypes': 'NIGHTCLUBS',
#    'months': '2018-10'}),
#  (20,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'robbery',
#    'location_types': 'Force',
#    'latitudes': '51.519888',
#    'longitudes': '-0.102506',
#    'street_ids': 961277,
#    'street_names': "On or near Greenhill's Rents",
#    'contexts': '',
#    'persistent_ids': '5bfec86d03b6c2e30d91e781235accee26d9b269a26c09df04dbb3bbc4e20c6e',
#    'crime_ids': 69211306,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (21,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'burglary',
#    'location_types': 'Force',
#    'latitudes': '51.511555',
#    'longitudes': '-0.126199',
#    'street_ids': 956512,
#    'street_names': 'On or near Garrick Street',
#    'contexts': '',
#    'persistent_ids': 'cf739c5ca13381cbb6c693bb6706aca3f18efa7fdaa64c362beaf65d8561980e',
#    'crime_ids': 69621341,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (22,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'public-order',
#    'location_types': 'Force',
#    'latitudes': '51.502410',
#    'longitudes': '-0.110538',
#    'street_ids': 953486,
#    'street_names': 'On or near Pear Place',
#    'contexts': '',
#    'persistent_ids': 'd697f2c05f78c3738f8a1ee3d37f5fbfbe34a0dce31d00809a7629297b2f00d4',
#    'crime_ids': 69577539,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (23,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.511715',
#    'longitudes': '-0.128902',
#    'street_ids': 956493,
#    'street_names': 'On or near Little Newport Street',
#    'contexts': '',
#    'persistent_ids': '6a9cfcd5b77ca50bd23f8ecc2a447245725bbbcd31bfac13f46fbf39f2f75eed',
#    'crime_ids': 66172331,
#    'location_subtypes': 'ROAD',
#    'months': '2018-06'}),
#  (24,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.514132',
#    'longitudes': '-0.132723',
#    'street_ids': 956464,
#    'street_names': 'On or near Royalty Mews',
#    'contexts': '',
#    'persistent_ids': '98392c11ba30652953c4faf5ba5d54615fc6ec1ba2223263785cb6ff57c076dd',
#    'crime_ids': 69223517,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (25,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'burglary',
#    'location_types': 'Force',
#    'latitudes': '51.516698',
#    'longitudes': '-0.135717',
#    'street_ids': 956636,
#    'street_names': 'On or near Berners Place',
#    'contexts': '',
#    'persistent_ids': '27c09d6a451dbb16bf311a2d2f98086f0feb9ede5120017b4cca8b11f53f2953',
#    'crime_ids': 69604378,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (26,
#   {'codes': 'not-guilty',
#    'procedures': 'Defendant found not guilty',
#    'dates': '2018-11',
#    'person_ids': 4114667.0,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.500961',
#    'longitudes': '-0.109330',
#    'street_ids': 953500,
#    'street_names': 'On or near Coral Street',
#    'contexts': '',
#    'persistent_ids': 'f666bfeaacee974df340fee823f5a82a7dabe4f96d0e8a5a1080a0c34b7c5b76',
#    'crime_ids': 61793460,
#    'location_subtypes': 'ROAD',
#    'months': '2017-12'}),
#  (27,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.504831',
#    'longitudes': '-0.102311',
#    'street_ids': 953744,
#    'street_names': 'On or near Dolben Street',
#    'contexts': '',
#    'persistent_ids': '9c03830b8797c1073dc1321e1181d77a6b0630e9da9b387c8e5176eb9ee5a167',
#    'crime_ids': 67310253,
#    'location_subtypes': 'ROAD',
#    'months': '2018-08'}),
#  (28,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.507309',
#    'longitudes': '-0.128348',
#    'street_ids': 956645,
#    'street_names': 'On or near Pedestrian Subway',
#    'contexts': '',
#    'persistent_ids': 'c52212db1017bab50964794a76bbf9a5675c5f98a46a6f89efdee6fe3a720874',
#    'crime_ids': 69207702,
#    'location_subtypes': 'SUBWAYS',
#    'months': '2018-09'}),
#  (29,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'robbery',
#    'location_types': 'Force',
#    'latitudes': '51.510051',
#    'longitudes': '-0.133971',
#    'street_ids': 956527,
#    'street_names': 'On or near Coventry Street',
#    'contexts': '',
#    'persistent_ids': '5ffe275cb1dc7b6594b405693363f90257d35e81012d0b3efd756a92ffaebcf4',
#    'crime_ids': 69606689,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (30,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'public-order',
#    'location_types': 'Force',
#    'latitudes': '51.510392',
#    'longitudes': '-0.135023',
#    'street_ids': 956545,
#    'street_names': 'On or near Nightclub',
#    'contexts': '',
#    'persistent_ids': '27747af7affdead1c5ea2ec463e54b3d5228117b16342a5efd3d18be46c81097',
#    'crime_ids': 69930523,
#    'location_subtypes': 'NIGHTCLUBS',
#    'months': '2018-11'}),
#  (31,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'shoplifting',
#    'location_types': 'Force',
#    'latitudes': '51.519987',
#    'longitudes': '-0.134487',
#    'street_ids': 960761,
#    'street_names': 'On or near Supermarket',
#    'contexts': '',
#    'persistent_ids': '55c13a970ad54a378581406c8b7a8011a5ae8c6f8d41dc927ba7d6a4ec0156de',
#    'crime_ids': 69930458,
#    'location_subtypes': 'SUPERMARKET CHAINS',
#    'months': '2018-11'}),
#  (32,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.512098',
#    'longitudes': '-0.139407',
#    'street_ids': 956308,
#    'street_names': 'On or near Parking Area',
#    'contexts': '',
#    'persistent_ids': '79dbc921a9c20e346bfce71f1f00ebd52ae429321340e6b77789e1548d6e8898',
#    'crime_ids': 69201993,
#    'location_subtypes': 'PARKING',
#    'months': '2018-09'}),
#  (33,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'theft-from-the-person',
#    'location_types': 'Force',
#    'latitudes': '51.518080',
#    'longitudes': '-0.126522',
#    'street_ids': 956630,
#    'street_names': 'On or near Great Russell Street',
#    'contexts': '',
#    'persistent_ids': 'e77b9b421b3ee5026ee463a139bddc9b3dc730638b2c35f0baa4cefa16b83703',
#    'crime_ids': 69971044,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (34,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.500969',
#    'longitudes': '-0.124933',
#    'street_ids': 953533,
#    'street_names': 'On or near Bridge Street',
#    'contexts': '',
#    'persistent_ids': 'aba23fdaa7effa27684caf4311648c3562332697501949a86ff729c2af643422',
#    'crime_ids': 69224355,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (35,
#   {'codes': 'cautioned',
#    'procedures': 'Offender given a caution',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.510827',
#    'longitudes': '-0.130697',
#    'street_ids': 956579,
#    'street_names': 'On or near Nightclub',
#    'contexts': '',
#    'persistent_ids': 'b7229512ec4dc32ca5074a00db45ee69255e7cfee0dd9dd2b3f93e279ad1a684',
#    'crime_ids': 69211141,
#    'location_subtypes': 'NIGHTCLUBS',
#    'months': '2018-09'}),
#  (36,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'burglary',
#    'location_types': 'Force',
#    'latitudes': '51.513166',
#    'longitudes': '-0.131336',
#    'street_ids': 956478,
#    'street_names': 'On or near Old Compton Street',
#    'contexts': '',
#    'persistent_ids': '9cd8da0d45bfba5588250d9e779eff773ff3961bc79b617e35d8ea1e536c72b6',
#    'crime_ids': 69209542,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (37,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.519912',
#    'longitudes': '-0.102332',
#    'street_ids': 961284,
#    'street_names': 'On or near Nightclub',
#    'contexts': '',
#    'persistent_ids': 'ae7ed89762c93bcc75b9549229b3cc2edfb3369809a56579763e043371699ca4',
#    'crime_ids': 69933544,
#    'location_subtypes': 'NIGHTCLUBS',
#    'months': '2018-11'}),
#  (38,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'theft-from-the-person',
#    'location_types': 'Force',
#    'latitudes': '51.516506',
#    'longitudes': '-0.131588',
#    'street_ids': 956596,
#    'street_names': 'On or near Supermarket',
#    'contexts': '',
#    'persistent_ids': '17c9f4d6fcc83de41ccf2476c2c20672b882ab6d372e40808b1f90af165b6e81',
#    'crime_ids': 69218152,
#    'location_subtypes': 'SUPERMARKET CHAINS',
#    'months': '2018-09'}),
#  (39,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'vehicle-crime',
#    'location_types': 'Force',
#    'latitudes': '51.503248',
#    'longitudes': '-0.100042',
#    'street_ids': 953727,
#    'street_names': 'On or near Risborough Street',
#    'contexts': '',
#    'persistent_ids': 'c797b78ffa331beaf3966a6640e6724515e719e1c217344176921ee19fe9e9ff',
#    'crime_ids': 69601346,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (40,
#   {'codes': 'cautioned',
#    'procedures': 'Offender given a caution',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.511922',
#    'longitudes': '-0.096511',
#    'street_ids': 587333,
#    'street_names': 'On or near Queen Victoria Street',
#    'contexts': '',
#    'persistent_ids': '1f6a06d45de303bcf2bf59ac094a7c70b47706b8c8a4b6e255673b83f3d7b02b',
#    'crime_ids': 69668736,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (41,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'public-order',
#    'location_types': 'Force',
#    'latitudes': '51.517871',
#    'longitudes': '-0.119108',
#    'street_ids': 956231,
#    'street_names': 'On or near Pedestrian Subway',
#    'contexts': '',
#    'persistent_ids': 'db209b59f201d415583409e24bbd1eb82e783136b126b62127e6939b721464dc',
#    'crime_ids': 69630938,
#    'location_subtypes': 'SUBWAYS',
#    'months': '2018-10'}),
#  (42,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'other-theft',
#    'location_types': 'Force',
#    'latitudes': '51.523357',
#    'longitudes': '-0.124720',
#    'street_ids': 960907,
#    'street_names': 'On or near Parking Area',
#    'contexts': '',
#    'persistent_ids': 'bdd78ebd141fef01aea21c9668a7efd589d321b79ddd8bafc64ae1082247b817',
#    'crime_ids': 69629090,
#    'location_subtypes': 'PARKING',
#    'months': '2018-10'}),
#  (43,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.505458',
#    'longitudes': '-0.114389',
#    'street_ids': 956276,
#    'street_names': 'On or near Waterloo Road',
#    'contexts': '',
#    'persistent_ids': '0058fc0957e312732e7235804bf75bb5bc59d1f416df6462cceda83b61a47a12',
#    'crime_ids': 69961901,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (44,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'vehicle-crime',
#    'location_types': 'Force',
#    'latitudes': '51.518709',
#    'longitudes': '-0.101345',
#    'street_ids': 587603,
#    'street_names': 'On or near Parking Area',
#    'contexts': '',
#    'persistent_ids': '73dc390512326ab1258ab1630e01c1be7575bfa9f1511791687539183eb9f04a',
#    'crime_ids': 67752904,
#    'location_subtypes': 'PARKING',
#    'months': '2018-08'}),
#  (45,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.515739',
#    'longitudes': '-0.100632',
#    'street_ids': 587318,
#    'street_names': 'On or near Warwick Lane',
#    'contexts': '',
#    'persistent_ids': '1a7de67974b5b5b09b42d367b53b101d79a6797c9c459503f1862468d1da5beb',
#    'crime_ids': 69668689,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (46,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'violent-crime',
#    'location_types': 'Force',
#    'latitudes': '51.518632',
#    'longitudes': '-0.114954',
#    'street_ids': 961047,
#    'street_names': 'On or near Brownlow Street',
#    'contexts': '',
#    'persistent_ids': 'a8974a554f60c679b9d1c47b3b0cf35bd198c4182ffbe3ccbc667e5e28387b26',
#    'crime_ids': 69261836,
#    'location_subtypes': 'ROAD',
#    'months': '2018-09'}),
#  (47,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'theft-from-the-person',
#    'location_types': 'Force',
#    'latitudes': '51.515948',
#    'longitudes': '-0.132707',
#    'street_ids': 956456,
#    'street_names': 'On or near Soho Street',
#    'contexts': '',
#    'persistent_ids': '703163ea4cfb26992e94d9a14a98030e432d9df9116c2c7aaaa827658e2d85d1',
#    'crime_ids': 69587829,
#    'location_subtypes': 'ROAD',
#    'months': '2018-10'}),
#  (48,
#   {'codes': 'local-resolution',
#    'procedures': 'Local resolution',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'possession-of-weapons',
#    'location_types': 'Force',
#    'latitudes': '51.500969',
#    'longitudes': '-0.124933',
#    'street_ids': 953533,
#    'street_names': 'On or near Bridge Street',
#    'contexts': '',
#    'persistent_ids': 'b157ddad0f9ea657545d9bb0ebeff8cce52079d4ee82a0cb0446cbf1a5b88dba',
#    'crime_ids': 69984042,
#    'location_subtypes': 'ROAD',
#    'months': '2018-11'}),
#  (49,
#   {'codes': 'no-further-action',
#    'procedures': 'Investigation complete; no suspect identified',
#    'dates': '2018-11',
#    'person_ids': nan,
#    'crime_categories': 'robbery',
#    'location_types': 'Force',
#    'latitudes': '51.503137',
#    'longitudes': '-0.113260',
#    'street_ids': 953516,
#    'street_names': 'On or near Police Station',
#    'contexts': '',
#    'persistent_ids': '64758744f3c0f27bf5be87fb44517dbc33a2eeb8dd92f8c2dc48946859138ee2',
#    'crime_ids': 69934878,
#    'location_subtypes': 'POLICE STATIONS',
#    'months': '2018-11'})]

# %% [markdown]
# **3. Outcome** == User requests a specific amount of records which is **bigger** than the total amount of records in the dictionary:

# %%
get_records("201811", "2000")
# Out:
# '<README>Do Not Panic! Your request has been successful. Unfortunatley the n_records paramter exeeds the amount of records in the dictionary. Try again by using either "All" in your path to retrive all records or inserting the amount of records you want to request.<README>'

# %% [markdown]
# ## 3. `Get_Code`:
# The `get_code` function allows the users to extract the whole list of `category codes` **count** for one specific date.
#
# `get_codes` takes in a `date` directly from the path specified in the `curl` request.

# %%
def get_code(date):#"get_code" has only one paramter ("date") which is given in the path.
    
    #Setting the API url:
    crime_url_template = 'https://data.police.uk/api/outcomes-at-location?lat={lat}&lng={lng}&date={data}'

    my_latitude = '51.509865' #The latitude of London City
    my_longitude = '-0.118092' #The longitute of London City
    extract_date = str(date) #Converting the "date" parameter given by the path to a string
    year = extract_date[0:4] #Slicing date in "year" (ex. "2018")
    month = extract_date[4:len(extract_date)] #Slicing date in "month" (ex. "11")
    my_date = year + "-" + month #Connecting "year" and "month" whilst adding a dash (ex. "2018-11")
   
    #Calling format on the API string to change {lat}, {lng}, {data} into the above-set paramters:
    crime_url = crime_url_template.format(
        lat = my_latitude,
        lng = my_longitude,
        data = my_date) 

    #Calling ".get" function to establish a connection with the Police API:
    resp = requests.get(crime_url)
    
    #If a "status_code" equal to 200 is returned then the resp in "json" format is returned:
    if resp.status_code == 200:
        all_crime_data = resp.json()

    #Else return the "status_code" of the respons:
    else:
        return resp.status_code
    
    #Create an empty list ("location") and an empty dictionary ("consequences"):
    location = []
    consequences = {}
    
    #Running a loop which iterates n_times (n = to the total records in the response dictionary):
    for i in range(len(all_crime_data)):
        
    #For every single "i" record in the response dictionary:
    
        #1. Take the code value in the category section of the record:
        row = all_crime_data[i]["category"]["code"]
        
        #2. Append the value to the location list:
        location.append(row)
 
        #3. Count the apperance of each entry:
        if row in consequences: 
            consequences[row] = consequences[row] +1 
        else:
            consequences[row] = 1

    #Transform the dictionary with the count of the apperances of each entry into a DataFrame:
    df_consequences = pd.DataFrame(list(consequences.items()), columns=['consequence', 'count'])

    #Utilise the vectorised functionalities of DataFrames to compute a new percentage column:
    df_consequences["percentage"] = df_consequences["count"] / df_consequences["count"].sum()
    
    #Cleaning column font:
    df_consequences["consequence"] = clean_col(df_consequences["consequence"])
    
    #Sort values in aseconding order and convert the new DataFrame back to a dictionary:
    consequences_dict = df_consequences.sort_values("percentage", ascending = True).to_dict("index")
  
    #Return the dictionary in json format:
    return consequences_dict

# %% [markdown]
# This is an example of an output for a request which is send to the `/code_count/201811` Path.

# %%
get_code("201811")
# Out:
# {14: {'consequence': 'sent_to_crown_court',
#   'count': 1,
#   'percentage': 0.0006341154090044388},
#  16: {'consequence': 'compensation',
#   'count': 2,
#   'percentage': 0.0012682308180088776},
#  15: {'consequence': 'drugs_possession_warning',
#   'count': 2,
#   'percentage': 0.0012682308180088776},
#  8: {'consequence': 'further_investigation_not_in_public_interest',
#   'count': 4,
#   'percentage': 0.0025364616360177552},
#  13: {'consequence': 'penalty_notice_issued',
#   'count': 8,
#   'percentage': 0.0050729232720355105},
#  9: {'consequence': 'unable_to_proceed',
#   'count': 9,
#   'percentage': 0.0057070386810399495},
#  10: {'consequence': 'conditional_discharge',
#   'count': 11,
#   'percentage': 0.006975269499048827},
#  12: {'consequence': 'community_penalty',
#   'count': 16,
#   'percentage': 0.010145846544071021},
#  4: {'consequence': 'not_guilty',
#   'count': 17,
#   'percentage': 0.01077996195307546},
#  7: {'consequence': 'suspended_sentence',
#   'count': 17,
#   'percentage': 0.01077996195307546},
#  0: {'consequence': 'unable_to_prosecute',
#   'count': 17,
#   'percentage': 0.01077996195307546},
#  11: {'consequence': 'fined', 'count': 23, 'percentage': 0.014584654407102092},
#  2: {'consequence': 'imprisoned',
#   'count': 31,
#   'percentage': 0.019657577679137603},
#  5: {'consequence': 'cautioned',
#   'count': 34,
#   'percentage': 0.02155992390615092},
#  6: {'consequence': 'local_resolution',
#   'count': 87,
#   'percentage': 0.055168040583386174},
#  3: {'consequence': 'awaiting_court_result',
#   'count': 156,
#   'percentage': 0.09892200380469246},
#  1: {'consequence': 'no_further_action',
#   'count': 1142,
#   'percentage': 0.7241597970830691}}

# %% [markdown]
# ## 3. `Get_Loc`:
# The `get_loc` function allows the users to extract the whole list of `crime_sublocation` **count** for one specific date.
#
# `get_loc` takes in a `date` directly from the path specified in the `curl` request.

# %%
def get_loc(date): #"get_loc" has only one paramter ("date") which is given in the path.
    
    #Setting the API url:
    crime_url_template = 'https://data.police.uk/api/outcomes-at-location?lat={lat}&lng={lng}&date={data}'

    my_latitude = '51.509865' #The latitude of London City
    my_longitude = '-0.118092' #The longitute of London City
    extract_date = str(date) #Converting the "date" parameter given by the path to a string
    year = extract_date[0:4] #Slicing date in "year" (ex. "2018")
    month = extract_date[4:len(extract_date)] #Slicing date in "month" (ex. "11")
    my_date = year + "-" + month #Connecting "year" and "month" whilst adding a dash (ex. "2018-11")
   
    #Calling format on the API string to change {lat}, {lng}, {data} into the above-set paramters:
    crime_url = crime_url_template.format(
        lat = my_latitude,
        lng = my_longitude,
        data = my_date) 

    #Calling ".get" function to establish a connection with the Police API:
    resp = requests.get(crime_url)
    
    #If a "status_code" equal to 200 is returned then the resp in "json" format is returned:
    if resp.status_code == 200:
        all_values = resp.json()

    #Else return the "status_code" of the respons:
    else:
        return resp.status_code

    #Create an empty list ("location") and an empty dictionary ("location_type"):
    location = []
    location_type = {}
    
    #Running a loop which iterates n_times (n = to the total records in the response dictionary):
    for i in range(len(all_values)):
        
    #For every single "i" record in the response dictionary:
    
        #1. Take the location_subtype value in the crime section of the record:
        row = all_values[i]["crime"]["location_subtype"]
         
        #2. Append the value to the location list:
        location.append(row)
        
        #3. Count the apperance of each entry:
        if row in location_type:
            location_type[row] =location_type[row] +1 
        else:
            location_type[row] = 1
    
    #Transform the dictionary with the count of the apperances of each entry into a DataFrame:
    df_location = pd.DataFrame(list(location_type.items()), columns=['location', 'count'])
    
    #Utilise the vectorised functionalities of DataFrames to compute a new percentage column:
    df_location["percentage"] = df_location["count"] / df_location["count"].sum()
    
    #Cleaning column strings:
    df_location["location"] = clean_col(df_location["location"])
    
    #Sort values in aseconding order and convert the new DataFrame back to a dictionary:
    loc_dict = df_location.sort_values("percentage", ascending = True).to_dict("index")
    
    #Return the dictionary in json format:
    return loc_dict

# %% [markdown]
# This is an example of an output for a request which is send to the `/location_count/201811` Path.

# %%
get_loc("201811")
# Out:
# {18: {'location': 'racecourses_and_greyhound_tracks',
#   'count': 1,
#   'percentage': 0.0006341154090044388},
#  16: {'location': 'bus_and_coach_stations,_depots_and_companies',
#   'count': 3,
#   'percentage': 0.0019023462270133164},
#  15: {'location': 'sports_grounds,_stadia_and_pitches',
#   'count': 3,
#   'percentage': 0.0019023462270133164},
#  12: {'location': 'hospitals', 'count': 7, 'percentage': 0.004438807863031071},
#  11: {'location': 'motorway_service_stations',
#   'count': 8,
#   'percentage': 0.0050729232720355105},
#  10: {'location': 'further_education_establishments',
#   'count': 8,
#   'percentage': 0.0050729232720355105},
#  17: {'location': 'shopping_centres_and_retail_parks',
#   'count': 8,
#   'percentage': 0.0050729232720355105},
#  8: {'location': 'markets', 'count': 9, 'percentage': 0.0057070386810399495},
#  13: {'location': 'conference_and_exhibition_centres',
#   'count': 11,
#   'percentage': 0.006975269499048827},
#  9: {'location': 'theme_and_adventure_parks',
#   'count': 12,
#   'percentage': 0.007609384908053266},
#  14: {'location': 'department_stores',
#   'count': 20,
#   'percentage': 0.012682308180088777},
#  5: {'location': 'subways', 'count': 22, 'percentage': 0.013950538998097653},
#  7: {'location': 'higher_education_establishments',
#   'count': 22,
#   'percentage': 0.013950538998097653},
#  6: {'location': 'police_stations',
#   'count': 30,
#   'percentage': 0.019023462270133164},
#  4: {'location': 'parking', 'count': 49, 'percentage': 0.031071655041217502},
#  3: {'location': 'supermarket_chains',
#   'count': 56,
#   'percentage': 0.03551046290424857},
#  2: {'location': 'theatres_and_concert_halls',
#   'count': 90,
#   'percentage': 0.05707038681039949},
#  1: {'location': 'nightclubs',
#   'count': 190,
#   'percentage': 0.12048192771084337},
#  0: {'location': 'road', 'count': 1028, 'percentage': 0.6518706404565631}}

# %% [markdown]
# ## 3. `Get_Crime`:
# The `get_crime` function allows the users to extract the whole list of `crime_category` **count** for one specific date.
#
# `get_crime` takes in a `date` directly from the path specified in the `curl` request.

# %%
def get_crime(date): #"get_crime" has only one paramter ("date") which is given in the path.
    
    #Setting the API url:
    crime_url_template = 'https://data.police.uk/api/outcomes-at-location?lat={lat}&lng={lng}&date={data}'

    my_latitude = '51.509865' #The latitude of London City
    my_longitude = '-0.118092' #The longitute of London City
    extract_date = str(date) #Converting the "date" parameter given by the path to a string
    year = extract_date[0:4] #Slicing date in "year" (ex. "2018")
    month = extract_date[4:len(extract_date)] #Slicing date in "month" (ex. "11")
    my_date = year + "-" + month #Connecting "year" and "month" whilst adding a dash (ex. "2018-11")
   
    #Calling format on the API string to change {lat}, {lng}, {data} into the above-set paramters:
    crime_url = crime_url_template.format(
        lat = my_latitude,
        lng = my_longitude,
        data = my_date) 

    #Calling ".get" function to establish a connection with the Police API:
    resp = requests.get(crime_url)
    
    #If a "status_code" equal to 200 is returned then the resp in "json" format is returned:
    if resp.status_code == 200:
        dicts = resp.json()

    #Else return the "status_code" of the response:
    else:
        return resp.status_code


    #Create an empty list ("location") and an empty dictionary ("crime_category"):
    location = []
    crime_category = {}
    
    #Running a loop which iterates n_times (n = to the total records in the response dictionary):
    for i in range(len(dicts)):
        
    #For every single "i" record in the response dictionary:
    
        #1. Take the category value in the crime section of the record:
        row = dicts[i]["crime"]["category"]
        
        #2. Append the value to the location list:
        location.append(row)
        
        #3. Count the apperance of each entry:
        if row in crime_category:
            crime_category[row] = crime_category[row] +1 
        else:
            crime_category[row] = 1
  
    #Transform the dictionary with the count of the apperances of each entry into a DataFrame:
    df_crimes = pd.DataFrame(list(crime_category.items()), columns=['crime', 'count'])
    
    #Utilise the vectorised functionalities of DataFrames to compute a new percentage column:
    df_crimes["percentage"] = df_crimes["count"] / df_crimes["count"].sum()
    
    #Cleaning column strings:
    df_crimes["crime"] = clean_col(df_crimes["crime"])
    
    #Sort values in aseconding order and convert the new DataFrame back to a dictionary:
    dict_crimes = df_crimes.sort_values("percentage", ascending = True).to_dict("index")
    
    #Return the dictionary in json format:
    return dict_crimes

# %% [markdown]
# This is an example of an output for a request which is send to the `/crime_count/201811` Path.

# %%
get_crime("201811")
# Out:
# {13: {'crime': '', 'count': 1, 'percentage': 0.0006341154090044388},
#  12: {'crime': 'other_crime', 'count': 14, 'percentage': 0.008877615726062143},
#  9: {'crime': 'possession_of_weapons',
#   'count': 28,
#   'percentage': 0.017755231452124286},
#  7: {'crime': 'vehicle_crime',
#   'count': 36,
#   'percentage': 0.022828154724159798},
#  10: {'crime': 'criminal_damage_arson',
#   'count': 40,
#   'percentage': 0.025364616360177554},
#  11: {'crime': 'bicycle_theft',
#   'count': 40,
#   'percentage': 0.025364616360177554},
#  2: {'crime': 'robbery', 'count': 91, 'percentage': 0.05770450221940393},
#  3: {'crime': 'theft_from_the_person',
#   'count': 110,
#   'percentage': 0.06975269499048826},
#  4: {'crime': 'burglary', 'count': 120, 'percentage': 0.07609384908053266},
#  5: {'crime': 'drugs', 'count': 124, 'percentage': 0.07863031071655041},
#  6: {'crime': 'public_order', 'count': 127, 'percentage': 0.08053265694356374},
#  8: {'crime': 'shoplifting', 'count': 138, 'percentage': 0.08750792644261256},
#  1: {'crime': 'other_theft', 'count': 343, 'percentage': 0.2175015852885225},
#  0: {'crime': 'violent_crime',
#   'count': 365,
#   'percentage': 0.23145212428662015}}
